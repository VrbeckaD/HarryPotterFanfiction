# %%
from IPython.display import display, HTML
import pandas as pd
import numpy

# %%
text = open("../lovers explit list cleaned.csv").read()

# %%
shiplist_raw = [line for line in text.split("\n")[1:] if "/" in line]

# %%
from collections import Counter, defaultdict

# %%
shiplist = sorted(Counter(shiplist_raw).items(), key=lambda x:x[1], reverse=True)

# %%
char_in_pair_freq = defaultdict(int)
for pair, score in shiplist:
    try: 
        left_name, right_name = pair.split("/")
    except:
        print(f"špatný počet lomítek v {pair}")
    char_in_pair_freq[left_name] += score
    char_in_pair_freq[right_name] += score
sorted_char_in_pairs = sorted(Counter(char_in_pair_freq).items(), key=lambda x:x[1], reverse=True)

# %%
print("Nechme si jen jména s frekvencí větší než 100, zbyde nám jmen:", len([(char, freq) for char, freq in sorted_char_in_pairs if freq >= 100]))
# Out:
# Nechme si jen jména s frekvencí větší než 100, zbyde nám jmen: 23

# %%
filtered_char_in_ship_23_best = [(char, freq) for char, freq in sorted_char_in_pairs if freq >= 100]

# %%
empty = numpy.zeros((len(filtered_char_in_ship_23_best), len(filtered_char_in_ship_23_best)), dtype=int)

# %%
filtered_shiplist = []
filtered_char_without_freq = [ship for ship, _ in filtered_char_in_ship_23_best]

def index(name):
    """Harry je na nulté pozici, když mu zadám Harry, vrátí 0."""
    return filtered_char_without_freq.index(name)

for ship, count in shiplist:
    left_name, right_name = ship.split("/")
    if left_name in filtered_char_without_freq and right_name in filtered_char_without_freq:
        filtered_shiplist.append((ship, count))
        if left_name == right_name:
            print("Sebevztah", left_name, count)
            empty[index(left_name), index(right_name)] = count
        else:
            empty[index(left_name), index(right_name)] = count
            empty[index(right_name), index(left_name)] = count
        
        
len(filtered_shiplist)
# Out:
# Sebevztah Hermione_Granger 1
# Sebevztah Tom_Riddle 1
# Sebevztah Albus_Dumbledore 1
# Sebevztah Gellert_Grindelwald 1
# Sebevztah Harry_Potter 1
# 121

# %%
from pandas import DataFrame

# %%
df = DataFrame(empty)

keep = numpy.triu(num.ones(df.shape)).astype('bool').reshape(df.size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ee9b2f0a84b2> in <module>
#       1 df = DataFrame(empty)
#       2
# ----> 3 keep = numpy.triu(num.ones(df.shape)).astype('bool').reshape(df.size)
#
# NameError: name 'num' is not defined

# %%
body = []
beautify_chars = [name.replace("_", "&nbsp;") for name in filtered_char_without_freq]
for row_number, name in enumerate(beautify_chars):
    start = f"<tr>"
    start += f"<td>{name}</td>"
    for col_number in range(len(beautify_chars)):
        value = empty[row_number, col_number]
        if col_number >= row_number:
            # obarvení podle hodnoty
            if value >= 500:
                start += f"<td style='background-color: #caffc4; width: 4ex'>{value}</td>"
            elif value >= 100:
                start += f"<td style='background-color: #c2e3bf; width: 4ex'>{value}</td>"
            elif value == 0:
                start += f"<td style='background-color: white; width: 4ex'>{value}</td>"
            else:
                start += f"<td style='background-color: #829487; width: 4ex'>{value}</td>"
        else:
            start += "<td></td>"
    start += "</tr>\n"
    body.append(start)

html_table = f"""
<table>
    <thead style="writing-mode: vertical-lr; text-orientation: use-glyph-orientation; text-align: right">
        <th></th><th>{"</th><th>".join(beautify_chars)}</th>
    </thead>
    {"".join(body)}
</table>
"""

# %%
HTML(html_table)
# Out:
# <table>
#     <thead style="writing-mode: vertical-lr; text-orientation: use-glyph-orientation; text-align: right">
#         <th></th><th>Harry&nbsp;Potter</th><th>Draco&nbsp;Malfoy</th><th>Hermione&nbsp;Granger</th><th>Severus&nbsp;Snape</th><th>Sirius&nbsp;Black</th><th>Remus&nbsp;Lupin</th><th>Original&nbsp;Percival&nbsp;Graves</th><th>Newt&nbsp;Scamander</th><th>Tom&nbsp;Riddle</th><th>Ginny&nbsp;Weasley</th><th>Credence&nbsp;Barebone</th><th>Voldemort</th><th>Ron&nbsp;Weasley</th><th>Lucius&nbsp;Malfoy</th><th>Gellert&nbsp;Grindelwald</th><th>Albus&nbsp;Dumbledore</th><th>Original&nbsp;Female&nbsp;Character</th><th>Theseus&nbsp;Scamander</th><th>James&nbsp;Potter</th><th>Pansy&nbsp;Parkinson</th><th>Scorpius&nbsp;Malfoy</th><th>Bellatrix&nbsp;Black&nbsp;Lestrange</th><th>Albus&nbsp;Severus&nbsp;Potter</th>
#     </thead>
#     <tr><td>Harry&nbsp;Potter</td><td style='background-color: #829487; width: 4ex'>1</td><td style='background-color: #caffc4; width: 4ex'>1929</td><td style='background-color: #c2e3bf; width: 4ex'>159</td><td style='background-color: #caffc4; width: 4ex'>508</td><td style='background-color: #829487; width: 4ex'>47</td><td style='background-color: #829487; width: 4ex'>16</td><td style='background-color: #829487; width: 4ex'>1</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #c2e3bf; width: 4ex'>202</td><td style='background-color: #c2e3bf; width: 4ex'>121</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #c2e3bf; width: 4ex'>178</td><td style='background-color: #829487; width: 4ex'>44</td><td style='background-color: #829487; width: 4ex'>22</td><td style='background-color: #829487; width: 4ex'>1</td><td style='background-color: #829487; width: 4ex'>6</td><td style='background-color: #829487; width: 4ex'>8</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>16</td><td style='background-color: #829487; width: 4ex'>18</td><td style='background-color: #829487; width: 4ex'>12</td><td style='background-color: #829487; width: 4ex'>4</td><td style='background-color: #829487; width: 4ex'>4</td></tr>
# <tr><td>Draco&nbsp;Malfoy</td><td></td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #caffc4; width: 4ex'>612</td><td style='background-color: #829487; width: 4ex'>23</td><td style='background-color: #829487; width: 4ex'>2</td><td style='background-color: #829487; width: 4ex'>3</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>4</td><td style='background-color: #829487; width: 4ex'>23</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>1</td><td style='background-color: #829487; width: 4ex'>54</td><td style='background-color: #829487; width: 4ex'>11</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>11</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>3</td><td style='background-color: #829487; width: 4ex'>5</td><td style='background-color: #829487; width: 4ex'>2</td><td style='background-color: #829487; width: 4ex'>1</td><td style='background-color: #829487; width: 4ex'>18</td></tr>
# <tr><td>Hermione&nbsp;Granger</td><td></td><td></td><td style='background-color: #829487; width: 4ex'>1</td><td style='background-color: #c2e3bf; width: 4ex'>284</td><td style='background-color: #829487; width: 4ex'>46</td><td style='background-color: #829487; width: 4ex'>19</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #c2e3bf; width: 4ex'>130</td><td style='background-color: #829487; width: 4ex'>14</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>23</td><td style='background-color: #829487; width: 4ex'>71</td><td style='background-color: #829487; width: 4ex'>79</td><td style='background-color: #829487; width: 4ex'>1</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>3</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>8</td><td style='background-color: #829487; width: 4ex'>50</td><td style='background-color: #829487; width: 4ex'>1</td><td style='background-color: #829487; width: 4ex'>72</td><td style='background-color: white; width: 4ex'>0</td></tr>
# <tr><td>Severus&nbsp;Snape</td><td></td><td></td><td></td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>38</td><td style='background-color: #829487; width: 4ex'>55</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>1</td><td style='background-color: #829487; width: 4ex'>6</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>9</td><td style='background-color: #829487; width: 4ex'>8</td><td style='background-color: #829487; width: 4ex'>36</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>8</td><td style='background-color: #829487; width: 4ex'>52</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>24</td><td style='background-color: #829487; width: 4ex'>1</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td></tr>
# <tr><td>Sirius&nbsp;Black</td><td></td><td></td><td></td><td></td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #c2e3bf; width: 4ex'>469</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>1</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>1</td><td style='background-color: #829487; width: 4ex'>6</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>12</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>30</td><td style='background-color: #829487; width: 4ex'>1</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>1</td><td style='background-color: white; width: 4ex'>0</td></tr>
# <tr><td>Remus&nbsp;Lupin</td><td></td><td></td><td></td><td></td><td></td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>3</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>10</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>2</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>1</td><td style='background-color:

# %%
frame = pd.DataFrame(data=empty, index=filtered_char_without_freq, columns=filtered_char_without_freq)

# %%
frame
# Out:
#                            Harry_Potter  Draco_Malfoy  Hermione_Granger  \
# Harry_Potter                          1          1929               159
# Draco_Malfoy                       1929             0               612
# Hermione_Granger                    159           612                 1
# Severus_Snape                       508            23               284
# Sirius_Black                         47             2                46
# Remus_Lupin                          16             3                19
# Original_Percival_Graves              1             0                 0
# Newt_Scamander                        0             0                 0
# Tom_Riddle                          202             4               130
# Ginny_Weasley                       121            23                14
# Credence_Barebone                     0             0                 0
# Voldemort                           178             1                23
# Ron_Weasley                          44            54                71
# Lucius_Malfoy                        22            11                79
# Gellert_Grindelwald                   1             0                 1
# Albus_Dumbledore                      6             0                 0
# Original_Female_Character             8            11                 3
# Theseus_Scamander                     0             0                 0
# James_Potter                         16             3                 8
# Pansy_Parkinson                      18             5                50
# Scorpius_Malfoy                      12             2                 1
# Bellatrix_Black_Lestrange             4             1                72
# Albus_Severus_Potter                  4            18                 0
#
#                            Severus_Snape  Sirius_Black  Remus_Lupin  \
# Harry_Potter                         508            47           16
# Draco_Malfoy                          23             2            3
# Hermione_Granger                     284            46           19
# Severus_Snape                          0            38           55
# Sirius_Black                          38             0          469
# Remus_Lupin                           55           469            0
# Original_Percival_Graves               0             0            0
# Newt_Scamander                         0             0            0
# Tom_Riddle                             1             0            0
# Ginny_Weasley                          6             1            0
# Credence_Barebone                      0             0            0
# Voldemort                              9             0            0
# Ron_Weasley                            8             1            0
# Lucius_Malfoy                         36             6            3
# Gellert_Grindelwald                    0             0            0
# Albus_Dumbledore                       8             0            0
# Original_Female_Character             52            12           10
# Theseus_Scamander                      0             0            0
# James_Potter                          24            30            2
# Pansy_Parkinson                        1             1            0
# Scorpius_Malfoy                        0             0            0
# Bellatrix_Black_Lestrange              0             1            1
# Albus_Severus_Potter                   0             0            0
#
#                            Original_Percival_Graves  Newt_Scamander  \
# Harry_Potter                                      1               0
# Draco_Malfoy                                      0               0
# Hermione_Granger                                  0               0
# Severus_Snape                                     0               0
# Sirius_Black                                      0               0
# Remus_Lupin                                       0               0
# Original_Percival_Graves                          0             142
# Newt_Scamander                                  142               0
# Tom_Riddle                                        0               0
# Ginny_Weasley                                     0               0
# Credence_Barebone                               188              21
# Voldemort                                         0               0
# Ron_Weasley                                       0               0
# Lucius_Malfoy                                     0               0
# Gellert_Grindelwald                              31               8
# Albus_Dumbledore                                  0              14
# Original_Female_Character                         2               0
# Theseus_Scamander                                17             135
# James_Potter                                      0               0
# Pansy_Parkinson                                   0               0
# Scorpius_Malfoy                                   0               0
# Bellatrix_Black_Lestrange                         0               0
# Albus_Severus_Potter                              0               0
#
#                            Tom_Riddle  Ginny_Weasley  ...  Lucius_Malfoy  \
# Harry_Potter                      202            121  ...             22
# Draco_Malfoy                        4             23  ...             11
# Hermione_Granger                  130             14  ...             79
# Severus_Snape                       1              6  ...             36
# Sirius_Black                        0              1  ...              6
# Remus_Lupin                         0              0  ...              3
# Original_Percival_Graves            0              0  ...              0
# Newt_Scamander                      0              0  ...              0
# Tom_Riddle                          1              2  ...              1
# Ginny_Weasley                       2              0  ...              2
# Credence_Barebone                   0              0  ...              0
# Voldemort                           1              0  ...              4
# Ron_Weasley                         1              7  ...              3
# Lucius_Malfoy                       1              2  ...              0
# Gellert_Grindelwald                 1              0  ...              0
# Albus_Dumbledore                    1              0  ...              0
# Original_Female_Character          19              1  ...              6
# Theseus_Scamander                   0              0  ...              0
# James_Potter                        0              1  ...              5
# Pansy_Parkinson                     1             19  ...              0
# Scorpius_Malfoy                     0              1  ...              0
# Bellatrix_Black_Lestrange           3              0  ...              2
# Albus_Severus_Potter                0              0  ...              0
#
#                            Gellert_Grindelwald  Albus_Dumbledore  \
# Harry_Potter                                 1                 6
# Draco_Malfoy                                 0                 0
# Hermione_Granger                             1                 0
# Severus_Snape                                0                 8
# Sirius_Black                                 0                 0
# Remus_Lupin                                  0                 0
# Original_Percival_Graves                    31                 0
# Newt_Scamander                               8                14
# Tom_Riddle                                   1                 1
# Ginny_Weasley                                0                 0
# Credence_Barebone                           12                 1
# Voldemort                                    0                 1
# Ron_Weasley                                  0                 0
# Lucius_Malfoy                                0                 0
# Gellert_Grindelwald                          1               142
# Albus_Dumbledore                           142                 1
# Original_Female_Character                    0                 0
# Theseus_Scamander                            3                 5
# James_Potter                                 0                 0
# Pansy_Parkinson                              0                 0
# Scorpius_Malfoy                              0                 0
# Bellatrix_Black_Lestrange                    0                 0
# Albus_Severus_Potter                         0                 0
#
#                            Original_Female_Character  Theseus_Scamander  \
# Harry_Potter                                       8                  0
# Draco_Malfoy                                      11                  0
# Hermione_Granger                                   3                  0
# Severus_Snape                                     52                  0
# Sirius_Black                                      12                  0
# Remus_Lupin                                       10                  0
# Original_Percival_Graves                           2                 17
# Newt_Scamander                                     0                135
# Tom_Riddle                                        19                  0
# Ginny_Weasley                                      1                  0
# Credence_Barebone                                  1                  2
# Voldemort                                          3                  0
# Ron_Weasley                                        2                  0
# Lucius_Malfoy                                      6                  0
# Gellert_Grindelwald                                0                  3
# Albus_Dumbledore                                   0                  5
# Original_Female_Character                          0                  0
# Theseus_Scamander                                  0                  0
# James_Potter                                       3                  0
# Pansy_Parkinson                                    0                  0
# Scorpius_Malfoy                                    0                  0
# Bellatrix_Black_Lestrange                          1                  0
# Albus_Severus_Potter                               2                  0
#
#                            James_Potter  Pansy_Parkinson  Scorpius_Malfoy  \
# Harry_Potter                         16               18               12
# Draco_Malfoy                          3                5                2
# Hermione_Granger                      8               50                1
# Severus_Snape                        24                1                0
# Sirius_Black                         30                1                0
# Remus_Lupin                           2                0                0
# Original_Percival_Graves              0                0                0
# Newt_Scamander                        0                0                0
# Tom_Riddle                            0                1                0
# Ginny_Weasley                         1               19                1
# Credence_Barebone                     0                0                0
# Voldemort                             0                0                0
# Ron_Weasley                           0               11                0
# Lucius_Malfoy                         5                0                0
# Gellert_Grindelwald                   0                0                0
# Albus_Dumbledore                      0                0                0
# Original_Female_Character             3                0                0
# Theseus_Scamander                     0                0                0
# James_Potter                          0                0                0
# Pansy_Parkinson                       0                0                0
# Scorpius_Malfoy                       0                0                0
# Bellatrix_Black_Lestrange             0                0                0
# Albus_Severus_Potter                  0                0               70
#
#                            Bellatrix_Black_Lestrange  Albus_Severus_Potter
# Harry_Potter                                       4                     4
# Draco_Malfoy                                       1                    18
# Hermione_Granger                                  72                     0
# Severus_Snape                                      0                     0
# Sirius_Black                                       1                     0
# Remus_Lupin                                        1                     0
# Original_Percival_Graves                           0                     0
# Newt_Scamander                                     0                     0
# Tom_Riddle                                         3                     0
# Ginny_Weasley                                      0                     0
# Credence_Barebone                                  0                     0
# Voldemort                                         16                     0
# Ron_Weasley                                        0                     0
# Lucius_Malfoy                                      2                     0
# Gellert_Grindelwald                                0                     0
# Albus_Dumbledore                                   0                     0
# Original_Female_Character                          1                     2
# Theseus_Scamander                                  0                     0
# James_Potter                                       0                     0
# Pansy_Parkinson                                    0                     0
# Scorpius_Malfoy                                    0                    70
# Bellatrix_Black_Lestrange                          0                     0
# Albus_Severus_Potter                               0                     0
#
# [23 rows x 23 columns]

# %%
frame.to_csv("lovers_matrix_explicit.csv")
