# %%
from IPython.display import display, HTML
import pandas as pd
import numpy

# %%
text = open("../Lovers list cleaned.csv").read()

# %%
shiplist_raw = [line for line in text.split("\n")[1:] if "/" in line]

# %%
from collections import Counter, defaultdict

# %%
shiplist = sorted(Counter(shiplist_raw).items(), key=lambda x:x[1], reverse=True)

# %%
char_in_pair_freq = defaultdict(int)
for pair, score in shiplist:
    try: 
        left_name, right_name = pair.split("/")
    except:
        print(f"špatný počet lomítek v {pair}")
    char_in_pair_freq[left_name] += score
    char_in_pair_freq[right_name] += score
sorted_char_in_pairs = sorted(Counter(char_in_pair_freq).items(), key=lambda x:x[1], reverse=True)

# %%
print("Nechme si jen jména s frekvencí větší než 100, zbyde nám jmen:", len([(char, freq) for char, freq in sorted_char_in_pairs if freq >= 100]))
# Out:
# Nechme si jen jména s frekvencí větší než 100, zbyde nám jmen: 66

# %%
filtered_char_in_ship_66_best = [(char, freq) for char, freq in sorted_char_in_pairs if freq >= 49]

# %%
empty = numpy.zeros((len(filtered_char_in_ship_66_best), len(filtered_char_in_ship_66_best)), dtype=int)

# %%
filtered_shiplist = []
filtered_char_without_freq = [ship for ship, _ in filtered_char_in_ship_103_best]

def index(name):
    """Harry je na nulté pozici, když mu zadám Harry, vrátí 0."""
    return filtered_char_without_freq.index(name)

for ship, count in shiplist:
    left_name, right_name = ship.split("/")
    if left_name in filtered_char_without_freq and right_name in filtered_char_without_freq:
        filtered_shiplist.append((ship, count))
        if left_name == right_name:
            print("Sebevztah", left_name, count)
            empty[index(left_name), index(right_name)] = count
        else:
            empty[index(left_name), index(right_name)] = count
            empty[index(right_name), index(left_name)] = count
        
        
len(filtered_shiplist)
# Out:
# Sebevztah Original_Character 32
# Sebevztah Original_Female_Character 11
# Sebevztah Original_Male_Character 11
# Sebevztah Hermione_Granger 2
# Sebevztah Albus_Dumbledore 2
# Sebevztah Gellert_Grindelwald 2
# Sebevztah Harry_Potter 2
# Sebevztah Lily_Evans_Potter 1
# Sebevztah Tom_Riddle 1
# Sebevztah Blaise_Zabini 1
# Sebevztah Pansy_Parkinson 1
# 1088

# %%
from pandas import DataFrame

# %%
df = DataFrame(empty)

keep = numpy.triu(num.ones(df.shape)).astype('bool').reshape(df.size)

# %%
body = []
beautify_chars = [name.replace("_", "&nbsp;") for name in filtered_char_without_freq]
for row_number, name in enumerate(beautify_chars):
    start = f"<tr>"
    start += f"<td>{name}</td>"
    for col_number in range(len(beautify_chars)):
        value = empty[row_number, col_number]
        if col_number >= row_number:
            # obarvení podle hodnoty
            if value >= 500:
                start += f"<td style='background-color: #caffc4; width: 4ex'>{value}</td>"
            elif value >= 100:
                start += f"<td style='background-color: #c2e3bf; width: 4ex'>{value}</td>"
            elif value == 0:
                start += f"<td style='background-color: white; width: 4ex'>{value}</td>"
            else:
                start += f"<td style='background-color: #829487; width: 4ex'>{value}</td>"
        else:
            start += "<td></td>"
    start += "</tr>\n"
    body.append(start)

html_table = f"""
<table>
    <thead style="writing-mode: vertical-lr; text-orientation: use-glyph-orientation; text-align: right">
        <th></th><th>{"</th><th>".join(beautify_chars)}</th>
    </thead>
    {"".join(body)}
</table>
"""

# %%
HTML(html_table)
# Out:
# <table>
#     <thead style="writing-mode: vertical-lr; text-orientation: use-glyph-orientation; text-align: right">
#         <th></th><th>Harry&nbsp;Potter</th><th>Draco&nbsp;Malfoy</th><th>Hermione&nbsp;Granger</th><th>Sirius&nbsp;Black</th><th>Severus&nbsp;Snape</th><th>Remus&nbsp;Lupin</th><th>Newt&nbsp;Scamander</th><th>James&nbsp;Potter</th><th>Ginny&nbsp;Weasley</th><th>Tom&nbsp;Riddle</th><th>Lily&nbsp;Evans&nbsp;Potter</th><th>Original&nbsp;Percival&nbsp;Graves</th><th>Original&nbsp;Female&nbsp;Character</th><th>Ron&nbsp;Weasley</th><th>Albus&nbsp;Dumbledore</th><th>Gellert&nbsp;Grindelwald</th><th>Voldemort</th><th>Scorpius&nbsp;Malfoy</th><th>Luna&nbsp;Lovegood</th><th>Albus&nbsp;Severus&nbsp;Potter</th><th>Pansy&nbsp;Parkinson</th><th>Lucius&nbsp;Malfoy</th><th>Credence&nbsp;Barebone</th><th>Reader</th><th>Tina&nbsp;Goldstein</th><th>Theseus&nbsp;Scamander</th><th>Bellatrix&nbsp;Black&nbsp;Lestrange</th><th>Neville&nbsp;Longbottom</th><th>Narcissa&nbsp;Black&nbsp;Malfoy</th><th>Charlie&nbsp;Weasley</th><th>Regulus&nbsp;Black</th><th>Fred&nbsp;Weasley</th><th>Oliver&nbsp;Wood</th><th>Nymphadora&nbsp;Tonks</th><th>Blaise&nbsp;Zabini</th><th>James&nbsp;Sirius&nbsp;Potter</th><th>Teddy&nbsp;Lupin</th><th>Theodore&nbsp;Nott</th><th>George&nbsp;Weasley</th><th>Percy&nbsp;Weasley</th><th>Original&nbsp;Character</th><th>Minerva&nbsp;McGonagall</th><th>Original&nbsp;Male&nbsp;Character</th><th>Fleur&nbsp;Delacour</th><th>Marcus&nbsp;Flint</th><th>Astoria&nbsp;Greengrass</th><th>Bill&nbsp;Weasley</th><th>Cedric&nbsp;Diggory</th><th>Daphne&nbsp;Greengrass</th><th>Dean&nbsp;Thomas</th><th>Rose&nbsp;Weasley</th><th>Seamus&nbsp;Finnigan</th><th>Tony&nbsp;Stark</th><th>Arthur&nbsp;Weasley</th><th>Queenie&nbsp;Goldstein</th><th>Viktor&nbsp;Krum</th><th>Lavender&nbsp;Brown</th><th>Leta&nbsp;Lestrange</th><th>Lily&nbsp;Luna&nbsp;Potter</th><th>Andromeda&nbsp;Black&nbsp;Tonks</th><th>Petunia&nbsp;Evans&nbsp;Dursley</th><th>Molly&nbsp;Weasley</th><th>Steve&nbsp;Rogers</th><th>Jacob&nbsp;Kowalski</th><th>Cho&nbsp;Chang</th><th>Rodolphus&nbsp;Lestrange</th><th>Loki&nbsp;(Marvel)</th><th>James&nbsp;Barnes</th><th>Parvati&nbsp;Patil</th><th>Marlene&nbsp;McKinnon</th><th>Victoire&nbsp;Weasley</th><th>Player&nbsp;Character&nbsp;(Hogwarts&nbsp;M
td><td style='background-color: #829487; width: 4ex'>8</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>13</td><td style='background-color: #829487; width: 4ex'>6</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>12</td><td style='background-color: #829487; width: 4ex'>3</td><td style='background-color: #829487; width: 4ex'>16</td><td style='background-color: #829487; width: 4ex'>8</td><td style='background-color: #829487; width: 4ex'>15</td><td style='background-color: white; width: 4ex'>0</td><td style='background-color: #829487; width: 4ex'>20</td><td style='background-color: #829487; width: 4ex'>5</td><td style='background-color: #829487; width: 4ex'>36</td><td style='background-color: #829487; width: 4ex'>14</td><td style='background-color: #829487; width: 4ex'>7</td><td style='background-color: white; width: 4ex'>0</t ...

# %%
frame = pd.DataFrame(data=empty, index=filtered_char_without_freq, columns=filtered_char_without_freq)

# %%
frame
# Out:
#                                                 Harry_Potter  Draco_Malfoy  \
# Harry_Potter                                               2             1
# Draco_Malfoy                                               1             0
# Hermione_Granger                                         891          2772
# Sirius_Black                                             199             9
# Severus_Snape                                           1717            65
# ...                                                      ...           ...
# Gellert_Grindelwald_pretending_Percival_Graves             0             0
# Padma_Patil                                                2             0
# Aziraphale                                                 0             0
# Alice_Longbottom                                           0             0
# Percy_Jackson                                             10             2
#
#                                                 Hermione_Granger  \
# Harry_Potter                                                 891
# Draco_Malfoy                                                2772
# Hermione_Granger                                               2
# Sirius_Black                                                 187
# Severus_Snape                                                922
# ...                                                          ...
# Gellert_Grindelwald_pretending_Percival_Graves                 0
# Padma_Patil                                                   11
# Aziraphale                                                     0
# Alice_Longbottom                                               0
# Percy_Jackson                                                  1
#
#                                                 Sirius_Black  Severus_Snape  \
# Harry_Potter                                             199           1717
# Draco_Malfoy                                               9             65
# Hermione_Granger                                         187            922
# Sirius_Black                                               0            143
# Severus_Snape                                            143              0
# ...                                                      ...            ...
# Gellert_Grindelwald_pretending_Percival_Graves             0              0
# Padma_Patil                                                0              0
# Aziraphale                                                 0              0
# Alice_Longbottom                                           2              1
# Percy_Jackson                                              0              0
#
#                                                 Remus_Lupin  Newt_Scamander  \
# Harry_Potter                                             50               1
# Draco_Malfoy                                              5               0
# Hermione_Granger                                         91               5
# Sirius_Black                                           3343               0
# Severus_Snape                                           191               0
# ...                                                     ...             ...
# Gellert_Grindelwald_pretending_Percival_Graves            0               3
# Padma_Patil                                               0               0
# Aziraphale                                                0               0
# Alice_Longbottom                                          0               0
# Percy_Jackson                                             0               0
#
#                                                 James_Potter  Ginny_Weasley  \
# Harry_Potter                                              26           1082
# Draco_Malfoy                                               4            153
# Hermione_Granger                                          32             85
# Sirius_Black                                             278              9
# Severus_Snape                                            106             14
# ...                                                      ...            ...
# Gellert_Grindelwald_pretending_Percival_Graves             0              0
# Padma_Patil                                                0              1
# Aziraphale                                                 0              0
# Alice_Longbottom                                           0              0
# Percy_Jackson                                              0              0
#
#                                                 Tom_Riddle  ...  \
# Harry_Potter                                          1185  ...
# Draco_Malfoy                                            13  ...
# Hermione_Granger                                       374  ...
# Sirius_Black                                             2  ...
# Severus_Snape                                           23  ...
# ...                                                    ...  ...
# Gellert_Grindelwald_pretending_Percival_Graves           0  ...
# Padma_Patil                                              1  ...
# Aziraphale                                               0  ...
# Alice_Longbottom                                         0  ...
# Percy_Jackson                                            0  ...
#
#                                                 Abraxas_Malfoy  Rubeus_Hagrid  \
# Harry_Potter                                                 1             13
# Draco_Malfoy                                                 0              1
# Hermione_Granger                                             7              4
# Sirius_Black                                                 0              1
# Severus_Snape                                                0             11
# ...                                                        ...            ...
# Gellert_Grindelwald_pretending_Percival_Graves               0              0
# Padma_Patil                                                  0              0
# Aziraphale                                                   0              0
# Alice_Longbottom                                             0              0
# Percy_Jackson                                                0              0
#
#                                                 Nagini  Dean_Winchester  \
# Harry_Potter                                         2               11
# Draco_Malfoy                                         0                0
# Hermione_Granger                                     0               14
# Sirius_Black                                         0                0
# Severus_Snape                                        0                0
# ...                                                ...              ...
# Gellert_Grindelwald_pretending_Percival_Graves       0                0
# Padma_Patil                                          0                0
# Aziraphale                                           0                0
# Alice_Longbottom                                     0                0
# Percy_Jackson                                        0                0
#
#                                                 Crowley_(Good_Omens)  \
# Harry_Potter                                                       1
# Draco_Malfoy                                                       0
# Hermione_Granger                                                   1
# Sirius_Black                                                       0
# Severus_Snape                                                      0
# ...                                                              ...
# Gellert_Grindelwald_pretending_Percival_Graves                     0
# Padma_Patil                                                        0
# Aziraphale                                                        55
# Alice_Longbottom                                                   0
# Percy_Jackson                                                      0
#
#                                                 Gellert_Grindelwald_pretending_Percival_Graves  \
# Harry_Potter                                                                                 0
# Draco_Malfoy                                                                                 0
# Hermione_Granger                                                                             0
# Sirius_Black                                                                                 0
# Severus_Snape                                                                                0
# ...                                                                                        ...
# Gellert_Grindelwald_pretending_Percival_Graves                                               0
# Padma_Patil                                                                                  0
# Aziraphale                                                                                   0
# Alice_Longbottom                                                                             0
# Percy_Jackson                                                                                0
#
#                                                 Padma_Patil  Aziraphale  \
# Harry_Potter                                              2           0
# Draco_Malfoy                                              0           0
# Hermione_Granger                                         11           0
# Sirius_Black                                              0           0
# Severus_Snape                                             0           0
# ...                                                     ...         ...
# Gellert_Grindelwald_pretending_Percival_Graves            0           0
# Padma_Patil                                               0           0
# Aziraphale                                                0           0
# Alice_Longbottom                                          0           0
# Percy_Jackson                                             0           0
#
#                                                 Alice_Longbottom  \
# Harry_Potter                                                   0
# Draco_Malfoy                                                   0
# Hermione_Granger                                               0
# Sirius_Black                                                   2
# Severus_Snape                                                  1
# ...                                                          ...
# Gellert_Grindelwald_pretending_Percival_Graves                 0
# Padma_Patil                                                    0
# Aziraphale                                                     0
# Alice_Longbottom                                               0
# Percy_Jackson                                                  0
#
#                                                 Percy_Jackson
# Harry_Potter                                               10
# Draco_Malfoy                                                2
# Hermione_Granger                                            1
# Sirius_Black                                                0
# Severus_Snape                                               0
# ...                                                       ...
# Gellert_Grindelwald_pretending_Percival_Graves              0
# Padma_Patil                                                 0
# Aziraphale                                                  0
# Alice_Longbottom                                            0
# Percy_Jackson                                               0
#
# [99 rows x 99 columns]

# %%
frame.to_csv("lovers_matrix_cleaned.csv")
